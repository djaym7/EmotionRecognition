# %%
import tensorflow as tf
import numpy as np
import pickle
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\djaym7\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def loadData(id):
    with open(f'y_train_{id}','rb') as f:
        y_train=np.array(pickle.load(f))
    with open(f'y_test_{id}','rb') as f:
        y_test=np.array(pickle.load(f))
    with open(f'X_train_{id}','rb') as f:
        X_train = np.array(pickle.load(f))
    with open(f'X_test_{id}','rb') as f:
        X_test = np.array(pickle.load(f))

    

    from sklearn.preprocessing import LabelBinarizer
    encoder = LabelBinarizer()
    y_train = encoder.fit_transform(y_train)
    y_test = encoder.fit_transform(y_test)


    print('X_train:',X_train.shape)
    print('X_test:',X_test.shape)
    print('y_train',y_train.shape) 
    print('y_test',y_test.shape) 

   
    return X_train,y_train,X_test,y_test

# %%
def result(y_pred,y_test,plot=False):
    y_pred_final=[] #getting final answers 
    y_test_final=[]
    for i in range((y_pred.shape[0])):
        y_pred_final.append(np.argmax(y_pred[i]))
        y_test_final.append(np.argmax(y_test[i]))

    y_pred_final_alpha=[]
    y_test_final_alpha=[]


    from sklearn.metrics import confusion_matrix,accuracy_score
    confusion_matrix = confusion_matrix(y_test_final,y_pred_final,labels=[0,1,2,3,4,5])
    print(confusion_matrix)
    print(accuracy_score(y_test_final,y_pred_final))


    #plot confusion matrix
    
    if plot == True:
        df_confusion_matrix  = pd.DataFrame(array)
        plt.figure(figsize = (10,10))
        plt.show()
        sn.heatmap(df_confusion_matrix, annot=True)
    return confusion_matrix

# %%
total_num_people=[]
for i in range(1,92):
    if i <10:
        total_num_people.append('100'+str(i))
    else:
        total_num_people.append('10'+str(i))
epochs = 150
batch_size = 300
results = []
confusionMatrix=[]
for i in total_num_people:
    X_train=[]
    X_test=[]
    y_train=[]
    y_test=[]
    X_train,y_train,X_test,y_test=loadData(i)
    

################################################### MODEL ##################################################################
    from attention import attention
    # Trying attention

    X = tf.placeholder(dtype=tf.float32,name='X',shape=(None,X_train.shape[1],X_train.shape[2]))
    y = tf.placeholder(dtype=tf.int32,name='y',shape=(None,y_train.shape[1]))


    cell0 = tf.nn.rnn_cell.LSTMCell(num_units=64,activation=tf.nn.tanh,dtype=tf.float32,name='lstm0')
    cell0= tf.nn.rnn_cell.DropoutWrapper(cell0,output_keep_prob=0.5)
    output0,states0 = tf.nn.dynamic_rnn(cell0,X,dtype=tf.float32,swap_memory=True)


    cell1 = tf.nn.rnn_cell.LSTMCell(num_units=128,activation=tf.nn.tanh,dtype=tf.float32,name='lstm1')
    cell1= tf.nn.rnn_cell.DropoutWrapper(cell1,output_keep_prob=0.5)
    output1,states1 = tf.nn.dynamic_rnn(cell1,output0,dtype=tf.float32,swap_memory=True)


    cell2 = tf.nn.rnn_cell.LSTMCell(num_units=128,activation=tf.nn.tanh,dtype=tf.float32,name='lstm2')
    cell2= tf.nn.rnn_cell.DropoutWrapper(cell2,output_keep_prob=0.5)
    output2,states2 = tf.nn.dynamic_rnn(cell2,output1,dtype=tf.float32,swap_memory=True)

    attention_output, alphas = attention(output2, 50, return_alphas=True)
    drop = tf.nn.dropout(attention_output,keep_prob=0.5)

    attention_states = tf.multiply(drop,states2[0]) #CONTEXT INSTEAD OF HS

    cell3 = tf.layers.dense(units=128,activation=tf.nn.relu,inputs=attention_states,name='dense')
    cell4 = tf.layers.dense(units=6,activation=None,inputs=cell3,name='dense2')


    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=cell4,labels=y))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    training_op = optimizer.minimize(loss)
    
    correct_prediction = tf.equal(tf.argmax(cell4, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    #init = tf.global_variables_initializer()
    predict = cell4

    
############################################################################################################################    
    
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch_no in range(epochs):
            for index, offset in enumerate(range(0, X_train.shape[0], batch_size)):
                xs, ys = X_train[offset: offset + batch_size], y_train[offset: offset + batch_size]
                sess.run(training_op, feed_dict={X: xs, y: ys})
                y_pred=sess.run(predict,feed_dict={X:X_test})

                
            los, acc = sess.run([loss, accuracy], feed_dict = {X: xs, y: ys})
            val_los, val_acc = sess.run([loss, accuracy], feed_dict = {X: X_test, y: y_test})
            print (f'id {i} epoch {epoch_no} index {index}, Loss: {los:.4f}, accuracy = {acc:.4f}, Val_loss ={val_los:.4f} , val_acc ={val_acc:.4f}')
    current_confusion_Mat = result(y_pred,y_test)
    confusionMatrix.append(current_confusion_Mat)
    results.append((val_los,val_acc))
    tf.reset_default_graph()
# Out:
# X_train: (7360, 500, 13)
# X_test: (82, 500, 13)
# y_train (7360, 6)
# y_test (82, 6)
# id 1001 epoch 0 index 24, Loss: 1.7212, accuracy = 0.2313, Val_loss =2.0913 , val_acc =0.1951
# id 1001 epoch 1 index 24, Loss: 1.4996, accuracy = 0.3375, Val_loss =2.1282 , val_acc =0.2195
# id 1001 epoch 2 index 24, Loss: 1.5168, accuracy = 0.4062, Val_loss =1.7610 , val_acc =0.2073
# id 1001 epoch 3 index 24, Loss: 1.4577, accuracy = 0.4500, Val_loss =1.9073 , val_acc =0.2317
# id 1001 epoch 4 index 24, Loss: 1.4872, accuracy = 0.3812, Val_loss =1.7519 , val_acc =0.1951
# id 1001 epoch 5 index 24, Loss: 1.4553, accuracy = 0.4250, Val_loss =1.8105 , val_acc =0.2805
# id 1001 epoch 6 index 24, Loss: 1.4171, accuracy = 0.4563, Val_loss =1.6897 , val_acc =0.3171
# id 1001 epoch 7 index 24, Loss: 1.4139, accuracy = 0.4500, Val_loss =1.7265 , val_acc =0.2317
# id 1001 epoch 8 index 24, Loss: 1.4394, accuracy = 0.4563, Val_loss =1.8119 , val_acc =0.2805
# id 1001 epoch 9 index 24, Loss: 1.3508, accuracy = 0.4875, Val_loss =1.8193 , val_acc =0.2561
# id 1001 epoch 10 index 24, Loss: 1.1956, accuracy = 0.5625, Val_loss =1.8012 , val_acc =0.2805
# id 1001 epoch 11 index 24, Loss: 1.1850, accuracy = 0.5813, Val_loss =1.9222 , val_acc =0.2927
# id 1001 epoch 12 index 24, Loss: 1.1958, accuracy = 0.5875, Val_loss =1.9147 , val_acc =0.3171
# id 1001 epoch 138 index 24, Loss: 0.0569, accuracy = 0.9812, Val_loss =4.2631 , val_acc =0.3415
# id 1001 epoch 139 index 24, Loss: 0.0815, accuracy = 0.9688, Val_loss =4.5259 , val_acc =0.3415
# id 1001 epoch 140 index 24, Loss: 0.0944, accuracy = 0.9688, Val_loss =3.8594 , val_acc =0.2317
# id 1001 epoch 141 index 24, Loss: 0.1200, accuracy = 0.9563, Val_loss =3.5643 , val_acc =0.3415
# id 1001 epoch 142 index 24, Loss: 0.1425, accuracy = 0.9625, Val_loss =4.0575 , val_acc =0.3293
# id 1001 epoch 143 index 24, Loss: 0.1536, accuracy = 0.9250, Val_loss =3.8860 , val_acc =0.3171
# id 1001 epoch 144 index 24, Loss: 0.0868, accuracy = 0.9750, Val_loss =3.6915 , val_acc =0.3902
# id 1001 epoch 145 index 24, Loss: 0.1710, accuracy = 0.9438, Val_loss =3.9863 , val_acc =0.3659
# id 1001 epoch 146 index 24, Loss: 0.0936, accuracy = 0.9688, Val_loss =3.9724 , val_acc =0.3293
# id 1001 epoch 147 index 24, Loss: 0.1054, accuracy = 0.9625, Val_loss =3.4029 , val_acc =0.3659
# id 1001 epoch 148 index 24, Loss: 0.0807, accuracy = 0.9875, Val_loss =3.7834 , val_acc =0.3049
# id 1001 epoch 149 index 24, Loss: 0.0539, accuracy = 0.9937, Val_loss =4.4222 , val_acc =0.3415
# [[6 1 0 4 3 0]
#  [3 2 2 4 3 0]
#  [4 0 2 5 3 0]
#  [4 0 1 5 4 0]
#  [2 0 0 4 6 0]
#  [2 1 1 2 5 3]]
# 0.2926829268292683
# X_train: (7361, 500, 13)
# X_test: (81, 500, 13)
# y_train (7361, 6)
# y_test (81, 6)
# id 1002 epoch 0 index 24, Loss: 1.5737, accuracy = 0.3292, Val_loss =1.9812 , val_acc =0.2099
# id 1002 epoch 1 index 24, Loss: 1.5363, accuracy = 0.3602, Val_loss =1.5247 , val_acc =0.3951
# id 1002 epoch 2 index 24, Loss: 1.4905, accuracy = 0.3789, Val_loss =1.4640 , val_acc =0.3827
# id 1002 epoch 3 index 24, Loss: 1.5114, accuracy = 0.4410, Val_loss =1.4613 , val_acc =0.4321
# id 1002 epoch 4 index 24, Loss: 1.4041, accuracy = 0.4286, Val_loss =1.4201 , val_acc =0.4691
# id 1002 epoch 5 index 24, Loss: 1.4411, accuracy = 0.4658, Val_loss =1.4329 , val_acc =0.4321
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-da70331fbcf2> in <module>()
#      68             for index, offset in enumerate(range(0, X_train.shape[0], batch_size)):
#      69                 xs, ys = X_train[offset: offset + batch_size], y_train[offset: offset + batch_size]
# ---> 70                 sess.run(training_op, feed_dict={X: xs, y: ys})
#      71                 y_pred=sess.run(predict,feed_dict={X:X_test})
#      72
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
