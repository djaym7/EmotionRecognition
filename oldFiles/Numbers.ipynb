# %%
import librosa
import python_speech_features as psf
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import os
import pandas as pd

# %% [markdown]
# # Librosa loads floating point time series,sr =22050, max_size = 110360

# %%
total_num_people = []
id_data=[]
FileNames=[]
address=r'C:\Users\djaym7\Desktop\Github\EmotionRecognition\AudioWAV/'

#making filenames
for i in range(1,92):
    if i <10:
        total_num_people.append('100'+str(i))
    else:
        total_num_people.append('10'+str(i))
for i in os.listdir(address):
    FileNames.append(i)
            

for id in total_num_people:
    id_data=[]
    for fname in FileNames:
        if id in fname:
            sound_clip,sr= librosa.load(address+fname)
            print('FileName-',fname,'\tSize-',len(sound_clip))
# Out:
# FileName- 1001_DFA_ANG_XX.wav 	Size- 50177
# FileName- 1001_DFA_DIS_XX.wav 	Size- 51502
# FileName- 1001_DFA_FEA_XX.wav 	Size- 47823
# FileName- 1001_DFA_HAP_XX.wav 	Size- 41201
# FileName- 1001_DFA_NEU_XX.wav 	Size- 44881
# FileName- 1001_DFA_SAD_XX.wav 	Size- 44145
# FileName- 1001_IEO_ANG_HI.wav 	Size- 42673
# FileName- 1001_IEO_ANG_LO.wav 	Size- 45616
# FileName- 1001_IEO_ANG_MD.wav 	Size- 58123
# FileName- 1001_IEO_DIS_HI.wav 	Size- 44145
# FileName- 1001_IEO_DIS_LO.wav 	Size- 44145
# FileName- 1001_IEO_DIS_MD.wav 	Size- 41937
# FileName- 1001_IEO_FEA_HI.wav 	Size- 34580
# FileName- 1001_IEO_FEA_LO.wav 	Size- 33844
# FileName- 1001_IEO_FEA_MD.wav 	Size- 35316
# FileName- 1001_IEO_HAP_HI.wav 	Size- 38995
# FileName- 1001_IEO_HAP_LO.wav 	Size- 37523
# FileName- 1001_IEO_HAP_MD.wav 	Size- 36787
# FileName- 1001_IEO_NEU_XX.wav 	Size- 35316
# FileName- 1001_IEO_SAD_HI.wav 	Size- 44145
# FileName- 1001_IEO_SAD_LO.wav 	Size- 41937
# FileName- 1001_IEO_SAD_MD.wav 	Size- 38259
# ...

# %%
sound_clip,sr= librosa.load(r"C:\Users\djaym7\Downloads\Music\The_Coasters__Searchinoriginal_and_best_quality_and_lyrics.mp3")

# %%
print('Duration in s: '+str(librosa.core.get_duration(sound_clip,sr)),' Sampled Data fp time series size :',len(sound_clip))
# Out:
# Duration in s: 2.06875283446712  Sampled Data fp time series size : 45616

# %%
plt.plot(sound_clip)

# %%
#import the pyplot and wavfile modules 

import matplotlib.pyplot as plot

from scipy.io import wavfile

 

# Read the wav file (mono)

#samplingFrequency, signalData = wavfile.read(r"C:\Users\djaym7\Desktop\Github\EmotionRecognition\AudioWAV\1001_DFA_ANG_XX.wav")

 

# Plot the signal read from wav file

plot.subplot(211)

plot.title('Spectrogram of a wav file with piano music')

#sound_clip = signalData

plot.plot(sound_clip)

plot.xlabel('Sample')

plot.ylabel('Amplitude')

 

plot.subplot(212)

plot.specgram(sound_clip,Fs=samplingFrequency)

plot.xlabel('Time')

plot.ylabel('Frequency')

 

plot.show()
# Out:
# C:\Users\djaym7\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7564: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Padding to max size

# %%
max_size = 110361
sound_clip=np.pad(sound_clip,pad_width=(0,max_size-len(sound_clip)),mode='constant')

# %%
plt.plot(sound_clip)

# %%
print('Duration in s: '+str(librosa.core.get_duration(sound_clip,sr)),' Sampled Data fp time series size :',len(sound_clip))
# Out:
# Duration in s: 5.005034013605442  Sampled Data fp time series size : 110361

# %%
data=[]
id_data=[]

address=r'C:\Users\djaym7\Desktop\Github\EmotionRecognition\AudioWAV/'
sound_clip,sr= librosa.load(address+'1001_DFA_ANG_XX.wav')
max_size = 110361
sound_clip=np.pad(sound_clip,pad_width=(0,max_size-len(sound_clip)),mode='constant')
#mfccs = extract_features(sound_clip,sr)  #old method
mfccs =psf.base.mfcc(sound_clip,samplerate=sr,winlen=0.01,winstep=0.01) #new lib

# %%
mfccs.shape
# Out:
# (500, 13)
