# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt

# %%
samples, sample_rate = librosa.load(f"C:\\Users\\djaym7\\Desktop\\Github\\EmotionRecognition\\AudioWAV\\1001_IEO_DIS_MD.wav")

# %%
plt.plot(samples)

# %%
samples_fft = np.fft.rfft(samples)
frequencies = np.abs(samples_fft)
plt.plot(frequencies)

# %%
samples.size
# Out:
# 41937

# %%
audio_length = len(samples)/sample_rate
audio_time_intervals = np.linspace(0,audio_length,499)
tempfreq = np.linspace(0,1,19)
plt.pcolormesh(audio_time_intervals, tempfreq, spectrogram2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f9b89dc22629> in <module>()
#       2 audio_time_intervals = np.linspace(0,audio_length,499)
#       3 tempfreq = np.linspace(0,1,19)
# ----> 4 plt.pcolormesh(audio_time_intervals, tempfreq, spectrogram2)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(*args, **kwargs)
#    3286                       mplDeprecation)
#    3287     try:
# -> 3288         ret = ax.pcolormesh(*args, **kwargs)
#    3289     finally:
#    3290         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, *args, **kwargs)
#    5928         allmatch = (shading == 'gouraud')
#    5929
# -> 5930         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    5931         Ny, Nx = X.shape
#    5932         X = X.ravel()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(funcname, *args, **kw)
#    5574                 raise TypeError('Dimensions of C %s are incompatible with'
#    5575                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 5576                                     C.shape, Nx, Ny, funcname))
#    5577             C = C[:Ny - 1, :Nx - 1]
#    5578         C = cbook.safe_masked_invalid(C)
#
# TypeError: Dimensions of C (43, 499) are incompatible with X (499) and/or Y (19); see help(pcolormesh)
